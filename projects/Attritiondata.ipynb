# %% [markdown]
# # **IMPORTING THE PYTHON PACKAGES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # **LOAD THE DATASETS **

# %%
Data = pd.read_csv("/content/Attrition data.csv")
Data
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 2              3   32        No  Travel_Frequently  Research & Development
# 3              4   38        No         Non-Travel  Research & Development
# 4              5   32        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
# ...

# %% [markdown]
# # **INFORMATION THE DATASETS**

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4410 entries, 0 to 4409
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   EmployeeID               4410 non-null   int64
#  1   Age                      4410 non-null   int64
#  2   Attrition                4410 non-null   object
#  3   BusinessTravel           4410 non-null   object
#  4   Department               4410 non-null   object
#  5   DistanceFromHome         4410 non-null   int64
#  6   Education                4410 non-null   int64
#  7   EducationField           4410 non-null   object
#  8   EmployeeCount            4410 non-null   int64
#  9   Gender                   4410 non-null   object
#  10  JobLevel                 4410 non-null   int64
#  11  JobRole                  4410 non-null   object
#  12  MaritalStatus            4410 non-null   object
#  13  MonthlyIncome            4410 non-null   int64
# ...

# %% [markdown]
# # **DATA SET DESCRIBE**

# %%
Data.describe()
# Out:
#         EmployeeID          Age  DistanceFromHome    Education  EmployeeCount  \
# count  4410.000000  4410.000000       4410.000000  4410.000000         4410.0
# mean   2205.500000    36.923810          9.192517     2.912925            1.0
# std    1273.201673     9.133301          8.105026     1.023933            0.0
# min       1.000000    18.000000          1.000000     1.000000            1.0
# 25%    1103.250000    30.000000          2.000000     2.000000            1.0
# 50%    2205.500000    36.000000          7.000000     3.000000            1.0
# 75%    3307.750000    43.000000         14.000000     4.000000            1.0
# max    4410.000000    60.000000         29.000000     5.000000            1.0
#
#           JobLevel  MonthlyIncome  NumCompaniesWorked  PercentSalaryHike  \
# count  4410.000000    4410.000000         4391.000000        4410.000000
# mean      2.063946   65029.312925            2.694830          15.209524
# ...

# %%
Data.head().copy()
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# 1                10          1  Life Sciences              1  Female  ...
# 2                17          4          Other              1    Male  ...
# 3                 2          5  Life Sciences              1    Male  ...
# 4                10          1        Medical              1    Male  ...
#
#    TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
Data.tail()
# Out:
#       EmployeeID  Age Attrition BusinessTravel              Department  \
# 4405        4406   42        No  Travel_Rarely  Research & Development
# 4406        4407   29        No  Travel_Rarely  Research & Development
# 4407        4408   25        No  Travel_Rarely  Research & Development
# 4408        4409   42        No  Travel_Rarely                   Sales
# 4409        4410   40        No  Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 4405                 5          4        Medical              1  Female  ...
# 4406                 2          4        Medical              1    Male  ...
# 4407                25          2  Life Sciences              1    Male  ...
# 4408                18          2        Medical              1    Male  ...
# 4409                28          3        Medical              1    Male  ...
#
#       TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
Data.count()
# Out:
# EmployeeID                 4410
# Age                        4410
# Attrition                  4410
# BusinessTravel             4410
# Department                 4410
# DistanceFromHome           4410
# Education                  4410
# EducationField             4410
# EmployeeCount              4410
# Gender                     4410
# JobLevel                   4410
# JobRole                    4410
# MaritalStatus              4410
# MonthlyIncome              4410
# NumCompaniesWorked         4391
# Over18                     4410
# PercentSalaryHike          4410
# StandardHours              4410
# StockOptionLevel           4410
# TotalWorkingYears          4401
# TrainingTimesLastYear      4410
# YearsAtCompany             4410
# YearsSinceLastPromotion    4410
# YearsWithCurrManager       4410
# EnvironmentSatisfaction    4385
# JobSatisfaction            4390
# WorkLifeBalance            4372
# JobInvolvement             4410
# PerformanceRating          4410
# ...

# %%
Data.head(10)
# Out:
#    EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0           1   51        No      Travel_Rarely                   Sales
# 1           2   31       Yes  Travel_Frequently  Research & Development
# 2           3   32        No  Travel_Frequently  Research & Development
# 3           4   38        No         Non-Travel  Research & Development
# 4           5   32        No      Travel_Rarely  Research & Development
# 5           6   46        No      Travel_Rarely  Research & Development
# 6           7   28       Yes      Travel_Rarely  Research & Development
# 7           8   29        No      Travel_Rarely  Research & Development
# 8           9   31        No      Travel_Rarely  Research & Development
# 9          10   25        No         Non-Travel  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 0                 6          2  Life Sciences              1  Female  ...
# ...

# %%
Data.tail(10)
# Out:
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 4400        4401   37        No      Travel_Rarely  Research & Development
# 4401        4402   45        No  Travel_Frequently                   Sales
# 4402        4403   37       Yes  Travel_Frequently                   Sales
# 4403        4404   39        No  Travel_Frequently  Research & Development
# 4404        4405   29        No      Travel_Rarely                   Sales
# 4405        4406   42        No      Travel_Rarely  Research & Development
# 4406        4407   29        No      Travel_Rarely  Research & Development
# 4407        4408   25        No      Travel_Rarely  Research & Development
# 4408        4409   42        No      Travel_Rarely                   Sales
# 4409        4410   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# ...

# %%
Data.nunique()
# Out:
# EmployeeID                 4410
# Age                          43
# Attrition                     2
# BusinessTravel                3
# Department                    3
# DistanceFromHome             29
# Education                     5
# EducationField                6
# EmployeeCount                 1
# Gender                        2
# JobLevel                      5
# JobRole                       9
# MaritalStatus                 3
# MonthlyIncome              1349
# NumCompaniesWorked           10
# Over18                        1
# PercentSalaryHike            15
# StandardHours                 1
# StockOptionLevel              4
# TotalWorkingYears            40
# TrainingTimesLastYear         7
# YearsAtCompany               37
# YearsSinceLastPromotion      16
# YearsWithCurrManager         18
# EnvironmentSatisfaction       4
# JobSatisfaction               4
# WorkLifeBalance               4
# JobInvolvement                4
# PerformanceRating             2
# ...

# %%
Data[(Data['Age']) > 21].count()
# Out:
# EmployeeID                 4287
# Age                        4287
# Attrition                  4287
# BusinessTravel             4287
# Department                 4287
# DistanceFromHome           4287
# Education                  4287
# EducationField             4287
# EmployeeCount              4287
# Gender                     4287
# JobLevel                   4287
# JobRole                    4287
# MaritalStatus              4287
# MonthlyIncome              4287
# NumCompaniesWorked         4269
# Over18                     4287
# PercentSalaryHike          4287
# StandardHours              4287
# StockOptionLevel           4287
# TotalWorkingYears          4278
# TrainingTimesLastYear      4287
# YearsAtCompany             4287
# YearsSinceLastPromotion    4287
# YearsWithCurrManager       4287
# EnvironmentSatisfaction    4263
# JobSatisfaction            4267
# WorkLifeBalance            4250
# JobInvolvement             4287
# PerformanceRating          4287
# ...

# %%
Gender_category = Data.groupby(['Gender'])
Gender_category

# %%
Gender_category.first()
# Out:
#         EmployeeID  Age Attrition     BusinessTravel              Department  \
# Gender
# Female           1   51        No      Travel_Rarely                   Sales
# Male             3   32        No  Travel_Frequently  Research & Development
#
#         DistanceFromHome  Education EducationField  EmployeeCount  JobLevel  \
# Gender
# Female                 6          2  Life Sciences              1         1
# Male                  17          4          Other              1         4
#
#         ... TotalWorkingYears TrainingTimesLastYear  YearsAtCompany  \
# Gender  ...
# Female  ...               1.0                     6               1
# Male    ...               5.0                     2               5
#
#         YearsSinceLastPromotion YearsWithCurrManager  EnvironmentSatisfaction  \
# Gender
# Female                        0                    0                      3.0
# Male                          0                    3                      2.0
#
# ...

# %%
for Gender, Gender_Data in Gender_category:
  print(Gender)
  print(Gender_Data)
# Out:
# ('Female',)
#       EmployeeID  Age Attrition     BusinessTravel              Department  \
# 0              1   51        No      Travel_Rarely                   Sales
# 1              2   31       Yes  Travel_Frequently  Research & Development
# 5              6   46        No      Travel_Rarely  Research & Development
# 9             10   25        No         Non-Travel  Research & Development
# 12            13   55        No      Travel_Rarely  Research & Development
# ...          ...  ...       ...                ...                     ...
# 4399        4400   34        No      Travel_Rarely  Research & Development
# 4400        4401   37        No      Travel_Rarely  Research & Development
# 4403        4404   39        No  Travel_Frequently  Research & Development
# 4404        4405   29        No      Travel_Rarely                   Sales
# 4405        4406   42        No      Travel_Rarely  Research & Development
#
# ...

# %%
Gender_category.get_group('Male').count()
# Out:
# EmployeeID                 2646
# Age                        2646
# Attrition                  2646
# BusinessTravel             2646
# Department                 2646
# DistanceFromHome           2646
# Education                  2646
# EducationField             2646
# EmployeeCount              2646
# Gender                     2646
# JobLevel                   2646
# JobRole                    2646
# MaritalStatus              2646
# MonthlyIncome              2646
# NumCompaniesWorked         2632
# Over18                     2646
# PercentSalaryHike          2646
# StandardHours              2646
# StockOptionLevel           2646
# TotalWorkingYears          2640
# TrainingTimesLastYear      2646
# YearsAtCompany             2646
# YearsSinceLastPromotion    2646
# YearsWithCurrManager       2646
# EnvironmentSatisfaction    2627
# JobSatisfaction            2633
# WorkLifeBalance            2622
# JobInvolvement             2646
# PerformanceRating          2646
# ...

# %%
Gender_category.get_group('Female').count()
# Out:
# EmployeeID                 1764
# Age                        1764
# Attrition                  1764
# BusinessTravel             1764
# Department                 1764
# DistanceFromHome           1764
# Education                  1764
# EducationField             1764
# EmployeeCount              1764
# Gender                     1764
# JobLevel                   1764
# JobRole                    1764
# MaritalStatus              1764
# MonthlyIncome              1764
# NumCompaniesWorked         1759
# Over18                     1764
# PercentSalaryHike          1764
# StandardHours              1764
# StockOptionLevel           1764
# TotalWorkingYears          1761
# TrainingTimesLastYear      1764
# YearsAtCompany             1764
# YearsSinceLastPromotion    1764
# YearsWithCurrManager       1764
# EnvironmentSatisfaction    1758
# JobSatisfaction            1757
# WorkLifeBalance            1750
# JobInvolvement             1764
# PerformanceRating          1764
# ...

# %%
Gender_category.get_group('Male').max()
# Out:
# EmployeeID                                 4410
# Age                                          60
# Attrition                                   Yes
# BusinessTravel                    Travel_Rarely
# Department                                Sales
# DistanceFromHome                             29
# Education                                     5
# EducationField                 Technical Degree
# EmployeeCount                                 1
# Gender                                     Male
# JobLevel                                      5
# JobRole                    Sales Representative
# MaritalStatus                            Single
# MonthlyIncome                            199730
# NumCompaniesWorked                          9.0
# Over18                                        Y
# PercentSalaryHike                            25
# StandardHours                                 8
# StockOptionLevel                              3
# TotalWorkingYears                          38.0
# ...

# %%
Gender_category.get_group('Male').min()
# Out:
# EmployeeID                                         3
# Age                                               18
# Attrition                                         No
# BusinessTravel                            Non-Travel
# Department                           Human Resources
# DistanceFromHome                                   1
# Education                                          1
# EducationField                       Human Resources
# EmployeeCount                                      1
# Gender                                          Male
# JobLevel                                           1
# JobRole                    Healthcare Representative
# MaritalStatus                               Divorced
# MonthlyIncome                                  10090
# NumCompaniesWorked                               0.0
# Over18                                             Y
# PercentSalaryHike                                 11
# StandardHours                                      8
# ...

# %%
Senior_age = Data.nlargest(5,'Age')
Senior_age
# Out:
#      EmployeeID  Age Attrition     BusinessTravel              Department  \
# 153         154   60        No      Travel_Rarely  Research & Development
# 169         170   60        No  Travel_Frequently  Research & Development
# 278         279   60        No      Travel_Rarely  Research & Development
# 621         622   60        No      Travel_Rarely                   Sales
# 951         952   60        No      Travel_Rarely                   Sales
#
#      DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 153                10          3  Life Sciences              1  Female  ...
# 169                16          3  Life Sciences              1  Female  ...
# 278                 8          2  Life Sciences              1  Female  ...
# 621                 2          2  Life Sciences              1    Male  ...
# 951                17          4        Medical              1    Male  ...
#
#      TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
Senior_age.copy()
# Out:
#      EmployeeID  Age Attrition     BusinessTravel              Department  \
# 153         154   60        No      Travel_Rarely  Research & Development
# 169         170   60        No  Travel_Frequently  Research & Development
# 278         279   60        No      Travel_Rarely  Research & Development
# 621         622   60        No      Travel_Rarely                   Sales
# 951         952   60        No      Travel_Rarely                   Sales
#
#      DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 153                10          3  Life Sciences              1  Female  ...
# 169                16          3  Life Sciences              1  Female  ...
# 278                 8          2  Life Sciences              1  Female  ...
# 621                 2          2  Life Sciences              1    Male  ...
# 951                17          4        Medical              1    Male  ...
#
#      TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
Senior_age_Table = Senior_age.copy()
Senior_age
# Out:
#      EmployeeID  Age Attrition     BusinessTravel              Department  \
# 153         154   60        No      Travel_Rarely  Research & Development
# 169         170   60        No  Travel_Frequently  Research & Development
# 278         279   60        No      Travel_Rarely  Research & Development
# 621         622   60        No      Travel_Rarely                   Sales
# 951         952   60        No      Travel_Rarely                   Sales
#
#      DistanceFromHome  Education EducationField  EmployeeCount  Gender  ...  \
# 153                10          3  Life Sciences              1  Female  ...
# 169                16          3  Life Sciences              1  Female  ...
# 278                 8          2  Life Sciences              1  Female  ...
# 621                 2          2  Life Sciences              1    Male  ...
# 951                17          4        Medical              1    Male  ...
#
#      TotalWorkingYears TrainingTimesLastYear YearsAtCompany  \
# ...

# %%
result_1 = sns.barplot(x = 'Department',y = 'Age', hue="Gender" , data = Senior_age , palette='Blues_d')
sns.color_palette()
plt.show()

# %%
Data.groupby(Data["TotalWorkingYears"]).max()
# Out:
#                    EmployeeID  Age Attrition BusinessTravel  \
# TotalWorkingYears
# 0.0                      4280   27       Yes  Travel_Rarely
# 1.0                      4330   51       Yes  Travel_Rarely
# 2.0                      4399   58       Yes  Travel_Rarely
# 3.0                      4281   58       Yes  Travel_Rarely
# 4.0                      4394   55       Yes  Travel_Rarely
# 5.0                      4408   56       Yes  Travel_Rarely
# 6.0                      4405   56       Yes  Travel_Rarely
# 7.0                      4393   59       Yes  Travel_Rarely
# 8.0                      4387   55       Yes  Travel_Rarely
# 9.0                      4402   58       Yes  Travel_Rarely
# 10.0                     4409   60       Yes  Travel_Rarely
# 11.0                     4380   53       Yes  Travel_Rarely
# 12.0                     4364   60       Yes  Travel_Rarely
# 13.0                     4400   59       Yes  Travel_Rarely
# ...

# %%
Data.groupby(Data["TotalWorkingYears"]).min()
# Out:
#                    EmployeeID  Age Attrition     BusinessTravel  \
# TotalWorkingYears
# 0.0                        39   18        No         Non-Travel
# 1.0                         1   19        No         Non-Travel
# 2.0                        35   20        No  Travel_Frequently
# 3.0                        17   21        No         Non-Travel
# 4.0                        37   22        No         Non-Travel
# 5.0                         3   23        No         Non-Travel
# 6.0                         2   24        No         Non-Travel
# 7.0                        16   25        No         Non-Travel
# 8.0                        20   26        No         Non-Travel
# 9.0                         5   27        No         Non-Travel
# 10.0                        8   28        No         Non-Travel
# 11.0                       48   29        No         Non-Travel
# 12.0                       26   30        No         Non-Travel
# ...

# %%
Data.describe().T
# Out:
#                           count          mean           std      min  \
# EmployeeID               4410.0   2205.500000   1273.201673      1.0
# Age                      4410.0     36.923810      9.133301     18.0
# DistanceFromHome         4410.0      9.192517      8.105026      1.0
# Education                4410.0      2.912925      1.023933      1.0
# EmployeeCount            4410.0      1.000000      0.000000      1.0
# JobLevel                 4410.0      2.063946      1.106689      1.0
# MonthlyIncome            4410.0  65029.312925  47068.888559  10090.0
# NumCompaniesWorked       4391.0      2.694830      2.498887      0.0
# PercentSalaryHike        4410.0     15.209524      3.659108     11.0
# StandardHours            4410.0      8.000000      0.000000      8.0
# StockOptionLevel         4410.0      0.793878      0.851883      0.0
# TotalWorkingYears        4401.0     11.279936      7.782222      0.0
# TrainingTimesLastYear    4410.0      2.799320      1.288978      0.0
# ...

# %%
missing_values = Data.isnull().sum()
missing_values
# Out:
# EmployeeID                  0
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# EnvironmentSatisfaction    25
# JobSatisfaction            20
# WorkLifeBalance            38
# JobInvolvement              0
# PerformanceRating           0
# dtype: int64
