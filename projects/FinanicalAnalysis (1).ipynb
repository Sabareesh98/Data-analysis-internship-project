# %% [markdown]
# **IMPORTING A DATASET**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **READING DATASETS**

# %%
plt.style.use('bmh')
Data = pd.read_excel('Financial Analytics data.xlsx')
Data
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore
# 0        1   Reliance Inds.        583436.72           99810.00
# 1        2              TCS        563709.84           30904.00
# 2        3        HDFC Bank        482953.59           20581.27
# 3        4              ITC        320985.27            9772.02
# 4        5          H D F C        289497.37           16840.51
# ..     ...              ...              ...                ...
# 483    496  Lak. Vilas Bank          3029.57             790.17
# 484    497            NOCIL          3026.26             249.27
# 485    498    Orient Cement          3024.32             511.53
# 486    499  Natl.Fertilizer          3017.07            2840.75
# 487    500        L T Foods              NaN                NaN
#
# [488 rows x 4 columns]

# %% [markdown]
# **INFORMATION ALL ABOUT THE DATASET**

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 0 to 487
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              488 non-null    int64
#  1   Name               488 non-null    object
#  2   Mar Cap - Crore    479 non-null    float64
#  3   Sales Qtr - Crore  459 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 15.4+ KB

# %% [markdown]
# **DESCRIBING ABOUT THE DATASETS**

# %%
Data.describe()
# Out:
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore
# count  488.000000       479.000000         459.000000
# mean   251.508197     28043.857119        3807.789412
# std    145.884078     59464.615831        9989.449987
# min      1.000000      3017.070000           0.000000
# 25%    122.750000      4843.575000         534.910000
# 50%    252.500000      9885.050000        1137.170000
# 75%    378.250000     23549.900000        2730.195000
# max    500.000000    583436.720000      110666.930000

# %% [markdown]
# **COUNT FUNCTION**

# %%
Data.count()
# Out:
# S.No.                488
# Name                 488
# Mar Cap - Crore      479
# Sales Qtr - Crore    459
# dtype: int64

# %% [markdown]
# **HEAD FUNCTION**

# %%
Data.head()
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51

# %% [markdown]
# **TAIL FUNCTION**

# %%
Data.tail()
# Out:
#      S.No.             Name  Mar Cap - Crore  Sales Qtr - Crore
# 483    496  Lak. Vilas Bank          3029.57             790.17
# 484    497            NOCIL          3026.26             249.27
# 485    498    Orient Cement          3024.32             511.53
# 486    499  Natl.Fertilizer          3017.07            2840.75
# 487    500        L T Foods              NaN                NaN

# %% [markdown]
# **CHECKING A NULL VALUES**

# %%
Data.isnull()
# Out:
#      S.No.   Name  Mar Cap - Crore  Sales Qtr - Crore
# 0    False  False            False              False
# 1    False  False            False              False
# 2    False  False            False              False
# 3    False  False            False              False
# 4    False  False            False              False
# ..     ...    ...              ...                ...
# 483  False  False            False              False
# 484  False  False            False              False
# 485  False  False            False              False
# 486  False  False            False              False
# 487  False  False             True               True
#
# [488 rows x 4 columns]

# %% [markdown]
# **CHECKING THE UNIQUE FUNCTION**

# %%
Data.nunique()
# Out:
# S.No.                488
# Name                 488
# Mar Cap - Crore      479
# Sales Qtr - Crore    459
# dtype: int64

# %%
Data.loc[0:4,'Name':'Mar Cap - Crore']
# Out:
#              Name  Mar Cap - Crore
# 0  Reliance Inds.        583436.72
# 1             TCS        563709.84
# 2       HDFC Bank        482953.59
# 3             ITC        320985.27
# 4         H D F C        289497.37

# %% [markdown]
# **TOP 5 COMPANY VALUES**

# %%
Top_5company = Data.nlargest(5,'Mar Cap - Crore')
Top_5company
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51

# %%
data_table = Top_5company.copy()
Top_5company
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51

# %% [markdown]
# **TOP 5 LOWEST SHARE VALUES**

# %%
Low_5Company_sale = Data.nsmallest(5,'Sales Qtr - Crore')
Low_5Company_sale
# Out:
#      S.No.              Name  Mar Cap - Crore  Sales Qtr - Crore
# 393    406  Ujjivan Fin.Ser.          4293.42               0.00
# 228    235             SPARC         10755.13              19.42
# 382    395   Tata Inv.Corpn.          4401.66              47.02
# 467    480  Central Dep. Ser          3316.31              47.24
# 422    435  Multi Comm. Exc.          3847.19              60.97

# %%
data_table = Low_5Company_sale.copy()
Low_5Company_sale
# Out:
#      S.No.              Name  Mar Cap - Crore  Sales Qtr - Crore
# 393    406  Ujjivan Fin.Ser.          4293.42               0.00
# 228    235             SPARC         10755.13              19.42
# 382    395   Tata Inv.Corpn.          4401.66              47.02
# 467    480  Central Dep. Ser          3316.31              47.24
# 422    435  Multi Comm. Exc.          3847.19              60.97

# %%
Share_holder = Data.groupby(['Name','Mar Cap - Crore'])['Sales Qtr - Crore'].max()
Share_holder
# Out:
# Name              Mar Cap - Crore
# 3M India          23101.19            645.77
# A B B             31983.33           2779.40
# ACC               30803.68           3494.24
# AIA Engg.         13593.35            572.16
# APL Apollo        4775.03            1314.38
#                                       ...
# Yes Bank          71028.13           5070.30
# Zee Entertainmen  54817.89           1838.07
# Zensar Tech.      4066.42             793.76
# Zydus Wellness    4921.45             132.40
# eClerx Services   5259.14             339.89
# Name: Sales Qtr - Crore, Length: 479, dtype: float64

# %%
result_1 = sns.barplot(x = 'Name',y = 'Sales Qtr - Crore', hue="Mar Cap - Crore" , data = Top_5company , palette='Blues_d')
sns.color_palette()
plt.show()

# %%
x = Top_5company ['Name']
y = Top_5company ['Sales Qtr - Crore']
plt.pie(y, labels=x, radius=1.2, autopct='%0.01f%%', shadow=True, explode=[.03,.2,.05,.02,.05])
plt.show()

# %%
x = Top_5company ['Name']
y = Top_5company ['Sales Qtr - Crore']
plt.xlabel('Name' ,fontsize=19)
plt.ylabel('Sales Qtr - Crore', fontsize=19)
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x = Low_5Company_sale ['Name']
y = Low_5Company_sale ['Sales Qtr - Crore']
plt.pie(y, labels=x, radius=1.2, autopct='%0.01f%%', shadow=True, explode=[.03,.2,.05,.02,.05])
plt.show()

# %%
x = Low_5Company_sale ['Name']
y = Low_5Company_sale ['Sales Qtr - Crore']
plt.xlabel('Name' ,fontsize=19)
plt.ylabel('Sales Qtr - Crore', fontsize=19)
plt.scatter(x,y)
plt.plot(x,y)
plt.show()
